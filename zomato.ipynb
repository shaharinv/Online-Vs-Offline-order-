# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/Users/doubledelight/population /Zomato-data-.csv")
df
# Out:
#                       name online_order book_table   rate  votes  \
# 0                    Jalsa          Yes        Yes  4.1/5    775
# 1           Spice Elephant          Yes         No  4.1/5    787
# 2          San Churro Cafe          Yes         No  3.8/5    918
# 3    Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4            Grand Village           No         No  3.8/5    166
# ..                     ...          ...        ...    ...    ...
# 143       Melting Melodies           No         No  3.3/5      0
# 144        New Indraprasta           No         No  3.3/5      0
# 145           Anna Kuteera          Yes         No  4.0/5    771
# 146                 Darbar           No         No  3.0/5     98
# 147          Vijayalakshmi          Yes         No  3.9/5     47
#
#      approx_cost(for two people) listed_in(type)
# 0                            800          Buffet
# 1                            800          Buffet
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         148 non-null    object
#  1   online_order                 148 non-null    object
#  2   book_table                   148 non-null    object
#  3   rate                         148 non-null    object
#  4   votes                        148 non-null    int64
#  5   approx_cost(for two people)  148 non-null    int64
#  6   listed_in(type)              148 non-null    object
# dtypes: int64(2), object(5)
# memory usage: 8.2+ KB

# %%
df['rate'] = df['rate'].astype(str)

# %%
df['rate'] = df['rate'].str.split('/').str[0]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         148 non-null    object
#  1   online_order                 148 non-null    object
#  2   book_table                   148 non-null    object
#  3   rate                         148 non-null    object
#  4   votes                        148 non-null    int64
#  5   approx_cost(for two people)  148 non-null    int64
#  6   listed_in(type)              148 non-null    object
# dtypes: int64(2), object(5)
# memory usage: 8.2+ KB

# %%
df['rate'] = pd.to_numeric(df['rate'], errors='coerce')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         148 non-null    object
#  1   online_order                 148 non-null    object
#  2   book_table                   148 non-null    object
#  3   rate                         148 non-null    float64
#  4   votes                        148 non-null    int64
#  5   approx_cost(for two people)  148 non-null    int64
#  6   listed_in(type)              148 non-null    object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 8.2+ KB

# %%
print(df.isnull().sum())
# Out:
# name                           0
# online_order                   0
# book_table                     0
# rate                           0
# votes                          0
# approx_cost(for two people)    0
# listed_in(type)                0
# dtype: int64

# %%
sns.countplot(x=df['listed_in(type)'])
plt.xlabel("type of restaurent")

# which type of restaurant most favoured by general public 
# answer is dining also can use this code 
df['listed_in(type)'].value_counts()
# Out:
# listed_in(type)
# Dining    110
# Cafes      23
# other       8
# Buffet      7
# Name: count, dtype: int64

# %%
grouped_data=df.groupby('listed_in(type)')['votes'].sum()
grouped_data
# Out:
# listed_in(type)
# Buffet     3028
# Cafes      6434
# Dining    20363
# other      9367
# Name: votes, dtype: int64

# %%
Final_table=pd.DataFrame({'votes':grouped_data})
Final_table
# Out:
#                  votes
# listed_in(type)
# Buffet            3028
# Cafes             6434
# Dining           20363
# other             9367

# %%
plt.plot(Final_table, c='green', marker='o')
plt.xlabel('Type of restaurant')
plt.ylabel('Votes')
# Out:
# Text(0, 0.5, 'Votes')

# %%
#identify the most voted restaurent
max_vote=df['votes'].max()
max_vote
df.loc[df['votes'].idxmax()]
# Out:
# name                           Empire Restaurant
# online_order                                 Yes
# book_table                                    No
# rate                                         4.4
# votes                                       4884
# approx_cost(for two people)                  750
# listed_in(type)                            other
# Name: 38, dtype: object

# %%
df.loc[df['votes'].idxmax(), 'name']
# Out:
# 'Empire Restaurant'

# %%
# Do prefer online order or not ??
sns.countplot(x=df['online_order'])
# Out:
# <Axes: xlabel='online_order', ylabel='count'>

# %%
# dining out vs cost

plt.hist(df['rate'],bins=5)
plt.title('Ratings Distribution')
plt.show()

# %%
#Approximate Cost for Couples
sns.countplot(x=df['approx_cost(for two people)'])

#Conclusion: The majority of couples prefer restaurants with an approximate cost of 300 rupees.
# Out:
# <Axes: xlabel='approx_cost(for two people)', ylabel='count'>

# %%
# Ratings Comparison - Online vs Offline Orders

plt.figure(figsize = (6,6))
sns.boxplot(x = 'online_order', y = 'rate', data = df)
# Out:
# <Axes: xlabel='online_order', ylabel='rate'>

# %% [markdown]
# Online orders have more rating than offline orders.

# %%
pivot_table = df.pivot_table(index='listed_in(type)', columns='online_order', aggfunc='size', fill_value=0)
sns.heatmap(pivot_table, annot=True, cmap='YlGnBu', fmt='d')
plt.title('Heatmap')
plt.xlabel('Online Order')
plt.ylabel('Listed In (Type)')
plt.show()
